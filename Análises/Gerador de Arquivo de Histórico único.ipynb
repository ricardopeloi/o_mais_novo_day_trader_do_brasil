# %% [markdown]
# # Bibliotecas

# %% [markdown]
# ## Sistema (os, makedirs, glob)

# %%
from os import makedirs
import os
import glob

# %% [markdown]
# ## Básicos (numpy, math, display, locale, time, random, re)

# %%
# !python -m pip install jupyter


# !python -m pip install IPython
from IPython.display import display

import math

# !python -m pip install numpy
import numpy as np

import locale
# locale.setlocale(locale.LC_ALL, "pt_BR.UTF-8")  # Use "" for auto, or force e.g. to "en_US.UTF-8"

import time
from datetime import datetime, timedelta, date

from pandas.tseries.offsets import BDay # para os dias úteis
# today = datetime.datetime.today()
# print(today - BDay(4)) # 4 dias úteis atrás

# # !python -m pip install random
import random
random.seed(42)

# !python -m pip install regex
import re

# %% [markdown]
# ## Leitura e análise de dados (Excel, Pandas, Spark)

# %%
# !python -m pip install findspark

# !python -m pip install openpyxl
# import openpyxl

# !python -m pip install xlsxwriter
# import xlsxwriter

# !python -m pip install xlrd
# import xlrd

# !python -m pip install python-calamine
# import python_calamine


# !python -m pip install pandas
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
# pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# ## Finanças (yfinance, mplfinance)

# %%
# https://pypi.org/project/yfinance/
# https://github.com/ranaroussi/yfinance/wiki/Ticker

# !python -m pip install yfinance
import yfinance as yf

# !python -m pip install mplfinance
# import mplfinance as mpf

# # Em R
# # https://cran.r-project.org/web/packages/BatchGetSymbols/index.html

# %% [markdown]
# # Funções

# %% [markdown]
# ## _criar_regressao_bd_acao_, _processar_regressao_e_lista_de_indicadores_, _candle_plot_, _plota_candlestick_acha_martelos_

# %%
# https://stackoverflow.com/questions/4383571/importing-files-from-different-folder

import sys
# caution: path[0] is reserved for script path (or '' in REPL)
sys.path.insert(1, r'C:\Users\ricardopeloi\OneDrive - falconi365\Data Science\O_Mais_Novo_Day_Trader_do_Brasil\o_mais_novo_day_trader_do_brasil')

# %% [markdown]
# # Refazendo arquivos

# %% [markdown]
# ## 1. ler_listaB3 e bd_lista_acoes

# %%
# import importlib
# try:
    # importlib.reload(sys.modules['receber_lista_atualizada_tickers'])
# except:
    # pass
# from receber_lista_atualizada_tickers import ler_lista_B3

# var_caminho = r"C:\Users\ricardopeloi\OneDrive - falconi365\Data Science\O_Mais_Novo_Day_Trader_do_Brasil\o_mais_novo_day_trader_do_brasil\Bases"
# bd_lista_acoes = ler_lista_B3(var_caminho)

# bd_lista_acoes

# %%
# bd_lista_acoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 403 entries, AZUL4 to BAUH4
# Data columns (total 3 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Nome da Empresa                    403 non-null    object
#  1   Volume no último dia útil          403 non-null    int64
#  2   Data da leitura (último dia útil)  403 non-null    datetime64[us]
# dtypes: datetime64[us](1), int64(1), object(1)
# memory usage: 12.6+ KB

# %% [markdown]
# ## 2. tratar_lista_B3 e bd_lista_acoes_tratada

# %%
# bd_lista_acoes_tratada_original = pd.read_excel(var_caminho + '/Lista de ações Tratada.xlsx')

# # var_coluna_volume = [item for item in bd_lista_acoes_tratada_original.columns if item.startswith("Volume no último dia útil")][0]

# # var_data_ultima_leitura = datetime.strptime(var_coluna_volume.split("lido em")[1].split(")")[0].strip(), "%d/%m/%Y")

# # bd_lista_acoes_tratada_original = bd_lista_acoes_tratada_original.rename(columns = {var_coluna_volume: "Volume no último dia útil"})
# # bd_lista_acoes_tratada_original["Data da leitura (último dia útil)"] = var_data_ultima_leitura

# bd_lista_acoes_tratada_original#.info()
# Out:
#     Ticker Nome da Empresa  Volume no último dia útil  \
# 0    COGN3           Cogna                  111753600
# 1    PETR4       Petrobras                   65752700
# 2    HAPV3         Hapvida                   57331500
# 3    ABEV3           Ambev                   56058800
# 4    MGLU3  Magazine Luiza                   26837300
# ..     ...             ...                        ...
# 243  LOGN3          Log-In                      24500
# 244  BIOM3           Biomm                      23700
# 245  PTNT4       Pettenati                      21300
# 246  ALUP4          Alupar                      20200
# 247  KRSA3      Kora Saúde                      20000
#
#                           industry              sector  fullTimeEmployees  \
# 0    Education & Training Services  Consumer Defensive          24,187.00
# 1             Oil & Gas Integrated              Energy          41,778.00
# 2                 Insurance - Life  Financial Services                NaN
# 3              Beverages - Brewers  Consumer Defensive          43,000.00
# 4                 Specialty Retail   Consumer Cyclical                NaN
# ..                             ...                 ...                ...
# 243                Marine Shipping         Industrials                NaN
# 244                  Biotechnology          Healthcare                NaN
# 245          Apparel Manufacturing   Consumer Cyclical                NaN
# 246          Utilities - Renewable           Utilities             906.00
# 247        Medical Care Facilities          Healthcare                NaN
#
#      dividendRate  dividendYield   exDividendDate  payoutRatio  ...  \
# 0            0.26          10.70 1,745,884,800.00         0.00  ...
# 1            7.09          22.98 1,744,848,000.00         2.01  ...
# 2             NaN            NaN 1,640,649,600.00         0.00  ...
# 3            0.80           5.68 1,742,169,600.00         0.73  ...
# 4            0.31           2.99 1,745,798,400.00         0.00  ...
# ..            ...            ...              ...          ...  ...
# 243           NaN            NaN 1,237,334,400.00         0.00  ...
# 244           NaN            NaN              NaN         0.00  ...
# 245          0.27           4.20 1,730,246,400.00         0.42  ...
# 246          0.32           3.36 1,744,848,000.00         0.42  ...
# 247           NaN            NaN              NaN         0.00  ...
#
#      operatingMargins  epsTrailingTwelveMonths  epsForward  epsCurrentYear  \
# 0                0.35                     0.46        0.18            0.26
# 1                0.10                     3.40        8.04            8.01
# 2               -0.01                    -0.09        0.29            0.20
# 3                0.28                     0.91        0.97            1.00
# 4                0.03                     0.61        0.61            0.49
# ..                ...                      ...         ...             ...
# 243              0.17                     1.41        2.22            0.86
# 244             -0.61                    -0.63         NaN             NaN
# 245              0.07                     0.65         NaN             NaN
# 246              0.61                     1.11         NaN             NaN
# 247              0.10                    -0.23        1.03             NaN
#
#      priceEpsCurrentYear  fiftyDayAverageChange  fiftyDayAverageChangePercent  \
# 0                   9.31                   0.59                          0.31
# 1                   3.85                  -4.69                         -0.13
# 2                  10.76                  -0.06                         -0.03
# 3                  13.97                   1.24                          0.10
# 4                  20.67                   1.23                          0.14
# ..                   ...                    ...                           ...
# 243                24.71                  -0.10                         -0.00
# 244                  NaN                  -0.10                         -0.01
# 245                  NaN                  -0.90                         -0.12
# 246                  NaN                   0.33                          0.04
# 247                  NaN                   0.14                          0.02
#
#      twoHundredDayAverageChange  twoHundredDayAverageChangePercent  \
# 0                          0.97                               0.65
# 1                         -6.05                              -0.16
# 2                         -0.96                              -0.31
# 3                          1.49                               0.12
# 4                          0.73                               0.08
# ..                          ...                                ...
# 243                       -5.79                              -0.21
# 244                        0.23                               0.02
# 245                       -0.17                              -0.03
# 246                        0.26                               0.03
# 247                        1.77                               0.25
#
#      Data da leitura (último dia útil)
# 0                           2025-04-19
# 1                           2025-04-19
# 2                           2025-04-19
# 3                           2025-04-19
# 4                           2025-04-19
# ..                                 ...
# 243                         2025-04-19
# 244                         2025-04-19
# 245                         2025-04-19
# 246                         2025-04-19
# 247                         2025-04-19
#
# [248 rows x 63 columns]

# %%
# import importlib
# try:
    # importlib.reload(sys.modules['receber_lista_atualizada_tickers'])
# except:
    # pass
# from receber_lista_atualizada_tickers import tratar_lista_B3

# # bd_lista_acoes_tratada = tratar_lista_B3(bd_lista_acoes.iloc[:5, :], var_caminho)
# bd_lista_acoes_tratada = tratar_lista_B3(bd_lista_acoes, var_caminho)

# bd_lista_acoes_tratada
# # bd_lista_acoes_tratada.info()
# Out:
# === LENDO DADOS DA AÇÃO ===
# 1 de 403; AZUL4
# 2 de 403; CRFB3
# 3 de 403; HAPV3
# 4 de 403; COGN3
# 5 de 403; B3SA3
# 6 de 403; ITSA4
# 7 de 403; PETR4
# 8 de 403; ITUB4
# 9 de 403; BEEF3
# 10 de 403; BBDC4
# 11 de 403; VALE3
# 12 de 403; CMIG4
# 13 de 403; ABEV3
# 14 de 403; RAIZ4
# 15 de 403; MGLU3
# 16 de 403; BBAS3
# 17 de 403; USIM5
# 18 de 403; CYRE3
# 19 de 403; LREN3
# 20 de 403; CPLE6
# 21 de 403; PCAR3
# 22 de 403; GGBR4
# 23 de 403; CSAN3
# 24 de 403; CCRO3
# 25 de 403; POMO4
# 26 de 403; PRIO3
# 27 de 403; SUZB3
# 28 de 403; CVCB3
# 29 de 403; RENT3
# 30 de 403; RAIL3
# 31 de 403; LWSA3
# 32 de 403; IFCM3
# 33 de 403; BRFS3
# 34 de 403; MRVE3
# 35 de 403; VAMO3
# 36 de 403; WEGE3
# 37 de 403; MULT3
# 38 de 403; PETR3
# 39 de 403; TIMS3
# 40 de 403; PETZ3
# 41 de 403; JBSS3
# 42 de 403; VBBR3
# 43 de 403; ELET3
# 44 de 403; CASH3
# 45 de 403; MRFG3
# 46 de 403; SRNA3
# 47 de 403; BRAP4
# 48 de 403; BPAC11
# 49 de 403; GOAU4
# 50 de 403; EQTL3
# 51 de 403; ENEV3
# 52 de 403; ANIM3
# 53 de 403; ASAI3
# 54 de 403; MOVI3
# 55 de 403; KLBN11
# 56 de 403; CSNA3
# 57 de 403; RDOR3
# 58 de 403; AZEV4
# 59 de 403; CPLE3
# 60 de 403; NTCO3
# 61 de 403; RADL3
# 62 de 403; CXSE3
# 63 de 403; AZTE3
# 64 de 403; AURE3
# 65 de 403; BBDC3
# 66 de 403; RECV3
# 67 de 403; CMIN3
# 68 de 403; GFSA3
# 69 de 403; ALOS3
?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=DASA11.SA&crumb=dA.Qhj35YWw
# 389 de 403; FESA3
# 390 de 403; ENMT4
# 391 de 403; EQMA3B
# 392 de 403; AHEB3
# 393 de 403; COCE3
# 394 de 403; BDLL4
# 395 de 403; USIM6
# 396 de 403; MAPT3
# 397 de 403; TKNO4
# 398 de 403; GPAR3
# 399 de 403; CGAS3
# 400 de 403; AHEB6
# 401 de 403; LUXM4
# 402 de 403; KRSA3
# 403 de 403; BAUH4
# === FIM LEITURA DOS DADOS DA AÇÃO ===
#     Ticker   Nome da Empresa  Volume no último dia útil  \
# 0    AZUL4              Azul                  282174900
# 1    CRFB3  Carrefour Brasil                   65204900
# 2    HAPV3           Hapvida                   64731600
# 3    COGN3             Cogna                   37935400
# 4    B3SA3                B3                   37609700
# ..     ...               ...                        ...
# 253  BIOM3             Biomm                      27500
# 254  BOBR4           Bombril                      25300
# 255  PTNT4         Pettenati                      23100
# 256  DEXP4            Dexxos                      20200
# 257  UCAS3           Unicasa                      20100
#
#     Data da leitura (último dia útil)                            industry  \
# 0          2025-04-26 13:14:47.711249                            Airlines
# 1          2025-04-26 13:14:47.711249                   Department Stores
# 2          2025-04-26 13:14:47.711249                    Insurance - Life
# 3          2025-04-26 13:14:47.711249       Education & Training Services
# 4          2025-04-26 13:14:47.711249    Financial Data & Stock Exchanges
# ..                                ...                                 ...
# 253        2025-04-26 13:14:47.711249                       Biotechnology
# 254        2025-04-26 13:14:47.711249       Household & Personal Products
# 255        2025-04-26 13:14:47.711249               Apparel Manufacturing
# 256        2025-04-26 13:14:47.711249                           Chemicals
# 257        2025-04-26 13:14:47.711249  Furnishings, Fixtures & Appliances
#
#                  sector  fullTimeEmployees  dividendRate  dividendYield  \
# 0           Industrials          15,367.00           NaN            NaN
# 1     Consumer Cyclical                NaN          0.10           1.11
# 2    Financial Services                NaN           NaN            NaN
# 3    Consumer Defensive          24,187.00          0.26          10.48
# 4    Financial Services                NaN          0.25           1.88
# ..                  ...                ...           ...            ...
# 253          Healthcare                NaN           NaN            NaN
# 254  Consumer Defensive           2,390.00           NaN            NaN
# 255   Consumer Cyclical                NaN          0.27           4.46
# 256     Basic Materials                NaN          0.86          10.95
# 257   Consumer Cyclical             516.00          0.18          11.49
#
#       exDividendDate  ...  ebitdaMargins  operatingMargins  \
# 0                NaN  ...           0.18              0.18
# 1   1,745,971,200.00  ...           0.05              0.04
# 2   1,640,649,600.00  ...           0.07             -0.01
# 3   1,745,884,800.00  ...           0.24              0.35
# 4   1,742,947,200.00  ...           0.66              0.63
# ..               ...  ...            ...               ...
# 253              NaN  ...          -0.49             -0.61
# 254              NaN  ...           0.14              0.11
# 255 1,730,246,400.00  ...           0.10              0.07
# 256 1,745,884,800.00  ...           0.14              0.09
# 257 1,733,443,200.00  ...           0.07             -0.02
#
#     epsTrailingTwelveMonths  epsForward  epsCurrentYear  priceEpsCurrentYear  \
# 0                     -0.35       -0.96           -1.53                -1.28
# 1                      0.83        0.79            0.59                14.70
# 2                     -0.09        0.29            0.20                12.01
# 3                      0.46        0.18            0.28                 9.07
# 4                      0.83        0.93            0.90                14.86
# ..                      ...         ...             ...                  ...
# 253                   -0.63         NaN             NaN                  NaN
# 254                    0.28         NaN             NaN                  NaN
# 255                    0.65         NaN             NaN                  NaN
# 256                    1.41         NaN             NaN                  NaN
# 257                    0.19        0.30             NaN                  NaN
#
#      fiftyDayAverageChange  fiftyDayAverageChangePercent  \
# 0                    -1.52                         -0.44
# 1                     0.95                          0.12
# 2                     0.20                          0.09
# 3                     0.55                          0.28
# 4                     1.62                          0.14
# ..                     ...                           ...
# 253                   0.26                          0.03
# 254                   0.00                          0.00
# 255                  -1.21                         -0.17
# 256                  -0.26                         -0.03
# 257                   0.09                          0.06
#
#      twoHundredDayAverageChange  twoHundredDayAverageChangePercent
# 0                         -2.95                              -0.60
# 1                          1.07                               0.14
# 2                         -0.67                              -0.22
# 3                          1.00                               0.67
# 4                          2.27                               0.20
# ..                          ...                                ...
# 253                        0.70                               0.07
# 254                       -0.39                              -0.19
# 255                       -0.55                              -0.08
# 256                       -0.90                              -0.10
# 257                       -0.33                              -0.17
#
# [252 rows x 63 columns]

# %%
# bd_lista_acoes_tratada_original = pd.read_excel(var_caminho + '/Lista de ações Tratada.xlsx')

# bd_lista_acoes_tratada_empilhada = pd.concat([bd_lista_acoes_tratada_original, bd_lista_acoes_tratada]).drop_duplicates(subset = ["Ticker", "Data da leitura (último dia útil)"]) \

# # bd_lista_acoes_tratada_empilhada.to_excel(var_caminho + '/Lista de ações Tratada.xlsx', index = False)

# bd_lista_acoes_tratada_empilhada
# Out:
#     Ticker Nome da Empresa  Volume no último dia útil  \
# 0    COGN3           Cogna                  111753600
# 1    PETR4       Petrobras                   65752700
# 2    HAPV3         Hapvida                   57331500
# 3    ABEV3           Ambev                   56058800
# 4    MGLU3  Magazine Luiza                   26837300
# ..     ...             ...                        ...
# 253  BIOM3           Biomm                      27500
# 254  BOBR4         Bombril                      25300
# 255  PTNT4       Pettenati                      23100
# 256  DEXP4          Dexxos                      20200
# 257  UCAS3         Unicasa                      20100
#
#                                industry              sector  \
# 0         Education & Training Services  Consumer Defensive
# 1                  Oil & Gas Integrated              Energy
# 2                      Insurance - Life  Financial Services
# 3                   Beverages - Brewers  Consumer Defensive
# 4                      Specialty Retail   Consumer Cyclical
# ..                                  ...                 ...
# 253                       Biotechnology          Healthcare
# 254       Household & Personal Products  Consumer Defensive
# 255               Apparel Manufacturing   Consumer Cyclical
# 256                           Chemicals     Basic Materials
# 257  Furnishings, Fixtures & Appliances   Consumer Cyclical
#
#      fullTimeEmployees  dividendRate  dividendYield   exDividendDate  \
# 0            24,187.00          0.26          10.70 1,745,884,800.00
# 1            41,778.00          7.09          22.98 1,744,848,000.00
# 2                  NaN           NaN            NaN 1,640,649,600.00
# 3            43,000.00          0.80           5.68 1,742,169,600.00
# 4                  NaN          0.31           2.99 1,745,798,400.00
# ..                 ...           ...            ...              ...
# 253                NaN           NaN            NaN              NaN
# 254           2,390.00           NaN            NaN              NaN
# 255                NaN          0.27           4.46 1,730,246,400.00
# 256                NaN          0.86          10.95 1,745,884,800.00
# 257             516.00          0.18          11.49 1,733,443,200.00
#
#      payoutRatio  ...  operatingMargins epsTrailingTwelveMonths  epsForward  \
# 0           0.00  ...              0.35                    0.46        0.18
# 1           2.01  ...              0.10                    3.40        8.04
# 2           0.00  ...             -0.01                   -0.09        0.29
# 3           0.73  ...              0.28                    0.91        0.97
# 4           0.00  ...              0.03                    0.61        0.61
# ..           ...  ...               ...                     ...         ...
# 253         0.00  ...             -0.61                   -0.63         NaN
# 254         0.00  ...              0.11                    0.28         NaN
# 255         0.42  ...              0.07                    0.65         NaN
# 256         0.52  ...              0.09                    1.41         NaN
# 257         0.96  ...             -0.02                    0.19        0.30
#
#      epsCurrentYear  priceEpsCurrentYear  fiftyDayAverageChange  \
# 0              0.26                 9.31                   0.59
# 1              8.01                 3.85                  -4.69
# 2              0.20                10.76                  -0.06
# 3              1.00                13.97                   1.24
# 4              0.49                20.67                   1.23
# ..              ...                  ...                    ...
# 253             NaN                  NaN                   0.26
# 254             NaN                  NaN                   0.00
# 255             NaN                  NaN                  -1.21
# 256             NaN                  NaN                  -0.26
# 257             NaN                  NaN                   0.09
#
#      fiftyDayAverageChangePercent  twoHundredDayAverageChange  \
# 0                            0.31                        0.97
# 1                           -0.13                       -6.05
# 2                           -0.03                       -0.96
# 3                            0.10                        1.49
# 4                            0.14                        0.73
# ..                            ...                         ...
# 253                          0.03                        0.70
# 254                          0.00                       -0.39
# 255                         -0.17                       -0.55
# 256                         -0.03                       -0.90
# 257                          0.06                       -0.33
#
#      twoHundredDayAverageChangePercent  Data da leitura (último dia útil)
# 0                                 0.65         2025-04-19 00:00:00.000000
# 1                                -0.16         2025-04-19 00:00:00.000000
# 2                                -0.31         2025-04-19 00:00:00.000000
# 3                                 0.12         2025-04-19 00:00:00.000000
# 4                                 0.08         2025-04-19 00:00:00.000000
# ..                                 ...                                ...
# 253                               0.07         2025-04-26 13:14:47.711249
# 254                              -0.19         2025-04-26 13:14:47.711249
# 255                              -0.08         2025-04-26 13:14:47.711249
# 256                              -0.10         2025-04-26 13:14:47.711249
# 257                              -0.17         2025-04-26 13:14:47.711249
#
# [752 rows x 63 columns]

# %% [markdown]
# ### Check da base gerada

# %%
# bd_lista_acoes_tratada_empilhada_import = pd.read_excel(var_caminho + "/Lista de ações Tratada.xlsx")
# bd_lista_acoes_tratada_empilhada_import
# Out:
#     Ticker Nome da Empresa  Volume no último dia útil  \
# 0    COGN3           Cogna                  111753600
# 1    PETR4       Petrobras                   65752700
# 2    HAPV3         Hapvida                   57331500
# 3    ABEV3           Ambev                   56058800
# 4    MGLU3  Magazine Luiza                   26837300
# ..     ...             ...                        ...
# 243  LOGN3          Log-In                      24500
# 244  BIOM3           Biomm                      23700
# 245  PTNT4       Pettenati                      21300
# 246  ALUP4          Alupar                      20200
# 247  KRSA3      Kora Saúde                      20000
#
#     Data da leitura (último dia útil)                       industry  \
# 0                          2025-04-19  Education & Training Services
# 1                          2025-04-19           Oil & Gas Integrated
# 2                          2025-04-19               Insurance - Life
# 3                          2025-04-19            Beverages - Brewers
# 4                          2025-04-19               Specialty Retail
# ..                                ...                            ...
# 243                        2025-04-19                Marine Shipping
# 244                        2025-04-19                  Biotechnology
# 245                        2025-04-19          Apparel Manufacturing
# 246                        2025-04-19          Utilities - Renewable
# 247                        2025-04-19        Medical Care Facilities
#
#                  sector  fullTimeEmployees  dividendRate  dividendYield  \
# 0    Consumer Defensive          24,187.00          0.26          10.70
# 1                Energy          41,778.00          7.09          22.98
# 2    Financial Services                NaN           NaN            NaN
# 3    Consumer Defensive          43,000.00          0.80           5.68
# 4     Consumer Cyclical                NaN          0.31           2.99
# ..                  ...                ...           ...            ...
# 243         Industrials                NaN           NaN            NaN
# 244          Healthcare                NaN           NaN            NaN
# 245   Consumer Cyclical                NaN          0.27           4.20
# 246           Utilities             906.00          0.32           3.36
# 247          Healthcare                NaN           NaN            NaN
#
#       exDividendDate  ...  ebitdaMargins  operatingMargins  \
# 0   1,745,884,800.00  ...           0.24              0.35
# 1   1,744,848,000.00  ...           0.40              0.10
# 2   1,640,649,600.00  ...           0.07             -0.01
# 3   1,742,169,600.00  ...           0.30              0.28
# 4   1,745,798,400.00  ...           0.04              0.03
# ..               ...  ...            ...               ...
# 243 1,237,334,400.00  ...           0.19              0.17
# 244              NaN  ...          -0.49             -0.61
# 245 1,730,246,400.00  ...           0.10              0.07
# 246 1,744,848,000.00  ...           0.73              0.61
# 247              NaN  ...           0.18              0.10
#
#      epsTrailingTwelveMonths  epsForward  epsCurrentYear  priceEpsCurrentYear  \
# 0                       0.46        0.18            0.26                 9.31
# 1                       3.40        8.04            8.01                 3.85
# 2                      -0.09        0.29            0.20                10.76
# 3                       0.91        0.97            1.00                13.97
# 4                       0.61        0.61            0.49                20.67
# ..                       ...         ...             ...                  ...
# 243                     1.41        2.22            0.86                24.71
# 244                    -0.63         NaN             NaN                  NaN
# 245                     0.65         NaN             NaN                  NaN
# 246                     1.11         NaN             NaN                  NaN
# 247                    -0.23        1.03             NaN                  NaN
#
#      fiftyDayAverageChange  fiftyDayAverageChangePercent  \
# 0                     0.59                          0.31
# 1                    -4.69                         -0.13
# 2                    -0.06                         -0.03
# 3                     1.24                          0.10
# 4                     1.23                          0.14
# ..                     ...                           ...
# 243                  -0.10                         -0.00
# 244                  -0.10                         -0.01
# 245                  -0.90                         -0.12
# 246                   0.33                          0.04
# 247                   0.14                          0.02
#
#      twoHundredDayAverageChange  twoHundredDayAverageChangePercent
# 0                          0.97                               0.65
# 1                         -6.05                              -0.16
# 2                         -0.96                              -0.31
# 3                          1.49                               0.12
# 4                          0.73                               0.08
# ..                          ...                                ...
# 243                       -5.79                              -0.21
# 244                        0.23                               0.02
# 245                       -0.17                              -0.03
# 246                        0.26                               0.03
# 247                        1.77                               0.25
#
# [248 rows x 63 columns]

# %%
# bd_lista_acoes_tratada_empilhada_import["Data da leitura (último dia útil)"].unique()

# bd_lista_acoes_tratada_empilhada_import = bd_lista_acoes_tratada_empilhada_import[~(bd_lista_acoes_tratada_empilhada_import["Data da leitura (último dia útil)"].isin(["2025-04-26 14:47:13.250000", "2025-04-26 13:14:47.711000"]))]

# bd_lista_acoes_tratada_empilhada_export = bd_lista_acoes_tratada_empilhada_import.copy()

# bd_lista_acoes_tratada_empilhada_export.to_excel(var_caminho + '/Lista de ações Tratada.xlsx', index = False)
# Out:
# C:\Users\ricardopeloi\AppData\Local\Temp\ipykernel_1732\1536113762.py:3: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   bd_lista_acoes_tratada_empilhada_import = bd_lista_acoes_tratada_empilhada_import[~(bd_lista_acoes_tratada_empilhada_import["Data da leitura (último dia útil)"].isin(["2025-04-26 14:47:13.250000", "2025-04-26 13:14:47.711000"]))]

# %%
# # bd_lista_acoes_tratada_empilhada

# bd_lista_acoes_tratada_empilhada_check = pd.pivot_table(
#     # data = bd_lista_acoes_tratada_empilhada[["Ticker", "Volume no último dia útil", "Data da leitura (último dia útil)"]],
#     data = bd_lista_acoes_tratada_empilhada_import[["Ticker", "Volume no último dia útil", "Data da leitura (último dia útil)"]],
#     index = "Ticker",
#     columns = "Data da leitura (último dia útil)",
#     values = "Volume no último dia útil",
#     aggfunc = "sum"
# )

# bd_lista_acoes_tratada_empilhada_check

# # for coluna in bd_lista_acoes_tratada_empilhada_check.columns:
#     # display(bd_lista_acoes_tratada_empilhada_check[bd_lista_acoes_tratada_empilhada_check[coluna].isna()])
# Out:
# Data da leitura (último dia útil)  2025-04-19
# Ticker
# AALR3                                  166800
# ABCB4                                  419600
# ABEV3                                56058800
# AERI3                                  212100
# AGRO3                                  408300
# ...                                       ...
# VVEO3                                 1862900
# WEGE3                                 3543500
# WIZC3                                  219500
# YDUQ3                                16381600
# ZAMP3                                  513800
#
# [248 rows x 1 columns]

# %% [markdown]
# ### Check final com as funções já ajustadas

# %%
# import importlib
# try:
    # importlib.reload(sys.modules['receber_lista_atualizada_tickers'])
# except:
    # pass
# from receber_lista_atualizada_tickers import tratar_lista_B3, ler_lista_B3

# bd_lista_acoes_tratada, bd_lista_acoes_tratada_empilhada = tratar_lista_B3(ler_lista_B3(var_caminho), var_caminho)

# # bd_lista_acoes_tratada
# bd_lista_acoes_tratada_empilhada
# Out:
# === IDENTIFICANDO AÇÕES ===
# AZUL4: Azul
# CRFB3: Carrefour Brasil
# HAPV3: Hapvida
# COGN3: Cogna
# B3SA3: B3
# ITSA4: Itaúsa
# PETR4: Petrobras
# ITUB4: Itaú Unibanco
# BEEF3: Minerva
# BBDC4: Banco Bradesco
# VALE3: Vale
# CMIG4: Cemig
# ABEV3: Ambev
# RAIZ4: Raízen
# MGLU3: Magazine Luiza
# BBAS3: Banco do Brasil
# USIM5: Usiminas
# CYRE3: Cyrela
# LREN3: Lojas Renner
# CPLE6: Copel
# PCAR3: Grupo Pão de Açúcar
# GGBR4: Gerdau
# CSAN3: Cosan
# CCRO3: Grupo CCR
# POMO4: Marcopolo
# PRIO3: PetroRio
# SUZB3: Suzano
# CVCB3: CVC
# RENT3: Localiza
# RAIL3: Rumo
# LWSA3: Locaweb
# IFCM3: Infracommerce
# BRFS3: BRF
# MRVE3: MRV
# VAMO3: Grupo Vamos
# WEGE3: WEG
# MULT3: Multiplan
# PETR3: Petrobras
# TIMS3: TIM
# PETZ3: Petz
# JBSS3: JBS
# VBBR3: Vibra Energia
# ELET3: Eletrobras
# CASH3: Méliuz
# MRFG3: Marfrig
# SRNA3: Serena Energia
# BRAP4: Bradespar
# BPAC11: Banco BTG Pactual
# GOAU4: Metalúrgica Gerdau
# EQTL3: Equatorial Energia
# ENEV3: Eneva
# ANIM3: Ânima Educação
# ASAI3: Assaí
# MOVI3: Movida
# KLBN11: Klabin
# CSNA3: Siderúrgica Nacional
# RDOR3: Rede D'Or
# AZEV4: Azevedo & Travassos
# CPLE3: Copel
# NTCO3: Natura
# RADL3: RaiaDrogasil
# CXSE3: Caixa Seguridade
# AZTE3: AZT Energia
# AURE3: Auren Energia
# BBDC3: Banco Bradesco
# RECV3: PetroRecôncavo
# CMIN3: CSN Mineração
# GFSA3: Gafisa
# ALOS3: Allos
# BRAV3: 3R Petroleum
# HYPE3: Hypera
# VIVT3: Vivo
# AMOB3: Automob
# ECOR3: EcoRodovias
# YDUQ3: YDUQS
# OIBR3: Oi
# JHSF3: JHSF
# TEND3: Construtora Tenda
# GMAT3: Grupo Mateus
# ENGI11: Energisa
# SIMH3: Simpar
# UGPA3: Ultrapar
# VIVA3: Vivara
# SBSP3: Sabesp
# STBP3: Santos Brasil
# CEAB3: C&A
# EMBR3: Embraer
# BBSE3: BB Seguridade
# SLCE3: SLC Agrícola
# BRKM5: Braskem
# SMFT3: Smart Fit
# CBAV3: CBA
# BHIA3: Casas Bahia
# ONCO3: Oncoclínicas
# ISAE4: ISA Energia
# CURY3: Cury
# EZTC3: EZTEC
# TAEE11: Taesa
# KEPL3: Kepler Weber
# SAPR4: Sanepar
# RCSL4: Recrusul
# SANB11: Banco Santander
# RAPT4: Randon
# FLRY3: Fleury
# TOTS3: Totvs
# AZZA3: Arezzo
# GOLL4: GOL
# SMTO3: São Martinho
# HBSA3: Hidrovias do Brasil
# ENJU3: Enjoei
# SBFG3: Grupo SBF
# AMER3: Americanas
# DIRR3: Direcional
# IGTI11: Iguatemi
# IGTI11: Jereissati Participações
# PMAM3: Paranapanema
# TTEN3: 3tentos
# AZEV3: Azevedo & Travassos
# CAML3: Camil Alimentos
# GGPS3: GPS
# SEER3: Ser Educacional
# GRND3: Grendene
# TUPY3: Tupy
# SAPR11: Sanepar
# ELET6: Eletrobras
# PSSA3: Porto Seguro
# QUAL3: Qualicorp
# BRSR6: Banrisul
# EGIE3: Engie
# ODPV3: Odontoprev
# ALPA4: Alpargatas
# CSMG3: COPASA
# INTB3: Intelbras
# DXCO3: Dexco
# ZAMP3: Zamp
# MLAS3: Multilaser
# KLBN4: Klabin
# GUAR3: Guararapes
# ALUP11: Alupar
# IRBR3: IRB Brasil RE
# CPFE3: CPFL Energia
# LAVV3: Lavvi Incorporadora
# CSED3: Cruzeiro do Sul Educacional
# EVEN3: Even
# BMOB3: Bemobi
# TFCO4: Track & Field
# LJQQ3: Lojas Quero-Quero
# MYPK3: Iochpe-Maxion
# VVEO3: Viveo
# PLPL3: Plano&Plano
# NEOE3: Neoenergia
# MTRE3: Mitre Realty
# HBOR3: Helbor
# SHUL4: Schulz
# MELK3: Melnick
# MDNE3: Moura Dubeux
# MILS3: Mills
# ABCB4: Banco ABC Brasil
# RANI3: Irani
# POSI3: Positivo
# ORVR3: Orizon
# MDIA3: M. Dias Branco
# JALL3: Jalles Machado
# FIQE3: Unifique
# PTBL3: Portobello
# BPAN4: Banco Pan
# SOJA3: Boa Safra Sementes
# ITUB3: Itaú Unibanco
# PGMN3: Pague Menos
# JSLG3: JSL
# SHOW3: Time For Fun
# VULC3: Vulcabras
# PDGR3: PDG Realty
# ARML3: Armac
# POMO3: Marcopolo
# USIM3: Usiminas
# ELMD3: Eletromidia
# LIGT3: Light
# TRIS3: Trisul
# VTRU3: VITRUBREPCOM
# KLBN3: Klabin
# PRNR3: Priner
# PINE4: Banco Pine
# SEQL3: Sequoia Logística
# WIZC3: Wiz Soluções
# MATD3: Mater Dei
# RNEW4: Renova Energia
# SYNE3: SYN
# PFRM3: Profarma
# MEAL3: IMC Alimentação
# RCSL3: Recrusul
# ESPA3: Espaçolaser
# BRAP3: Bradespar
# PNVL3: Dimed
# OPCT3: OceanPact
# LEVE3: Mahle Metal Leve
# DESK3: Desktop
# PORT3: Wilson Sons
# TGMA3: Tegma
# CMIG3: Cemig
# LOGG3: LOG CP
# FRAS3: Fras-le
# AERI3: Aeris Energy
# TCSA3: Tecnisa
# SAPR3: Sanepar
# TAEE4: Taesa
# DASA3: Dasa
# TASA4: Taurus
# BLAU3: Blau Farmacêutica
# FESA4: Ferbasa
# BRBI11: BR Partners
# BRST3: Brisanet
# VITT3: Vittia
# BMGB4: Banco BMG
# HBRE3: HBR Realty
# AGRO3: BrasilAgro
# MBLY3: Mobly
# VLID3: Valid
# INEP3: Inepar
# RNEW3: Renova Energia
# AGXY3: AgroGalaxy
# SANB4: Banco Santander
# AMAR3: Lojas Marisa
# ROMI3: Indústrias ROMI
# TAEE3: Taesa
# LPSB3: Lopes
# IGTI3: Iguatemi
# IGTI3: Jereissati Participações
# DEXP3: Dexxos
# TECN3: Technos
# INEP4: Inepar
# ALPK3: Estapar
# AALR3: Alliança
# VSTE3: LE LIS BLANC
# SANB3: Banco Santander
# RNEW11: Renova Energia
# VIVR3: Viver
# CSUD3: CSU Cardsystem
# ITSA3: Itaúsa
# AMBP3: Ambipar
# DMVF3: D1000 Varejo Farma
# ALLD3: Allied
# OIBR4: Oi
# EUCA4: Eucatex
# PDTC3: Padtec
# ENGI4: Energisa
# UNIP6: Unipar
# TRAD3: Traders Club
# GOAU3: Metalúrgica Gerdau
# ETER3: Eternit
# TPIS3: Triunfo
# CAMB3: Cambuci
# LVTC3: WDC Networks
# SCAR3: São Carlos
# LUPA3: Lupatech
# BIOM3: Biomm
# BOBR4: Bombril
# PTNT4: Pettenati
# DEXP4: Dexxos
# UCAS3: Unicasa
# ATED3: ATOM EDUCAÇÃO E EDITORA S.A.
# RSID3: Rossi Residencial
# CTSA4: Santanense
# GGBR3: Gerdau
# OFSA3: Ourofino Saúde Animal
# === FIM LEITURA DOS DADOS DA AÇÃO ===
#      Ticker   Nome da Empresa  Volume no último dia útil  \
# 0     AZUL4              Azul                  282174900
# 1     CRFB3  Carrefour Brasil                   65204900
# 2     HAPV3           Hapvida                   64731600
# 3     COGN3             Cogna                   37935400
# 4     B3SA3                B3                   37609700
# ...     ...               ...                        ...
# 1251  LOGN3            Log-In                      24500
# 1252  BIOM3             Biomm                      23700
# 1253  PTNT4         Pettenati                      21300
# 1254  ALUP4            Alupar                      20200
# 1255  KRSA3        Kora Saúde                      20000
#
#      Data da leitura (último dia útil)                          industry  \
# 0                           2025-04-26                          Airlines
# 1                           2025-04-26                 Department Stores
# 2                           2025-04-26                  Insurance - Life
# 3                           2025-04-26     Education & Training Services
# 4                           2025-04-26  Financial Data & Stock Exchanges
# ...                                ...                               ...
# 1251                        2025-04-19                   Marine Shipping
# 1252                        2025-04-19                     Biotechnology
# 1253                        2025-04-19             Apparel Manufacturing
# 1254                        2025-04-19             Utilities - Renewable
# 1255                        2025-04-19           Medical Care Facilities
#
#                   sector  fullTimeEmployees  dividendRate  dividendYield  \
# 0            Industrials          15,367.00           NaN            NaN
# 1      Consumer Cyclical                NaN          0.10           1.11
# 2     Financial Services                NaN           NaN            NaN
# 3     Consumer Defensive          24,187.00          0.26          10.48
# 4     Financial Services                NaN          0.25           1.88
# ...                  ...                ...           ...            ...
# 1251         Industrials                NaN           NaN            NaN
# 1252          Healthcare                NaN           NaN            NaN
# 1253   Consumer Cyclical                NaN          0.27           4.20
# 1254           Utilities             906.00          0.32           3.36
# 1255          Healthcare                NaN           NaN            NaN
#
#        exDividendDate  ...  ebitdaMargins  operatingMargins  \
# 0                 NaN  ...           0.18              0.18
# 1    1,745,971,200.00  ...           0.05              0.04
# 2    1,640,649,600.00  ...           0.07             -0.01
# 3    1,745,884,800.00  ...           0.24              0.35
# 4    1,742,947,200.00  ...           0.66              0.63
# ...               ...  ...            ...               ...
# 1251 1,237,334,400.00  ...           0.19              0.17
# 1252              NaN  ...          -0.49             -0.61
# 1253 1,730,246,400.00  ...           0.10              0.07
# 1254 1,744,848,000.00  ...           0.73              0.61
# 1255              NaN  ...           0.18              0.10
#
#      epsTrailingTwelveMonths  epsForward  epsCurrentYear  priceEpsCurrentYear  \
# 0                      -0.35       -0.96           -1.53                -1.28
# 1                       0.83        0.79            0.59                14.70
# 2                      -0.09        0.29            0.20                12.01
# 3                       0.46        0.18            0.28                 9.07
# 4                       0.83        0.93            0.90                14.86
# ...                      ...         ...             ...                  ...
# 1251                    1.41        2.22            0.86                24.71
# 1252                   -0.63         NaN             NaN                  NaN
# 1253                    0.65         NaN             NaN                  NaN
# 1254                    1.11         NaN             NaN                  NaN
# 1255                   -0.23        1.03             NaN                  NaN
#
#       fiftyDayAverageChange  fiftyDayAverageChangePercent  \
# 0                     -1.52                         -0.44
# 1                      0.95                          0.12
# 2                      0.20                          0.09
# 3                      0.55                          0.28
# 4                      1.62                          0.14
# ...                     ...                           ...
# 1251                  -0.10                         -0.00
# 1252                  -0.10                         -0.01
# 1253                  -0.90                         -0.12
# 1254                   0.33                          0.04
# 1255                   0.14                          0.02
#
#       twoHundredDayAverageChange  twoHundredDayAverageChangePercent
# 0                          -2.95                              -0.60
# 1                           1.07                               0.14
# 2                          -0.67                              -0.22
# 3                           1.00                               0.67
# 4                           2.27                               0.20
# ...                          ...                                ...
# 1251                       -5.79                              -0.21
# 1252                        0.23                               0.02
# 1253                       -0.17                              -0.03
# 1254                        0.26                               0.03
# 1255                        1.77                               0.25
#
# [1256 rows x 63 columns]

# %%
# bd_lista_acoes_tratada_empilhada = bd_lista_acoes_tratada_empilhada[~(bd_lista_acoes_tratada_empilhada["Data da leitura (último dia útil)"].isin(["2025-04-26 14:58:12.306", "2025-04-26 15:00:00.000", "2025-04-26 15:06:24.698"]))]
# Out:
# C:\Users\ricardopeloi\AppData\Local\Temp\ipykernel_1732\208725787.py:1: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   bd_lista_acoes_tratada_empilhada = bd_lista_acoes_tratada_empilhada[~(bd_lista_acoes_tratada_empilhada["Data da leitura (último dia útil)"].isin(["2025-04-26 14:58:12.306", "2025-04-26 15:00:00.000", "2025-04-26 15:06:24.698"]))]

# %%
# bd_lista_acoes_tratada_empilhada_check = pd.pivot_table(
#     data = bd_lista_acoes_tratada_empilhada[["Ticker", "Volume no último dia útil", "Data da leitura (último dia útil)"]],
#     # data = bd_lista_acoes_tratada_empilhada_import[["Ticker", "Volume no último dia útil", "Data da leitura (último dia útil)"]],
#     index = "Ticker",
#     columns = "Data da leitura (último dia útil)",
#     values = "Volume no último dia útil",
#     aggfunc = "sum"
# )

# bd_lista_acoes_tratada_empilhada_check
# Out:
# Data da leitura (último dia útil)    2025-04-19    2025-04-26
# Ticker
# AALR3                                166,800.00     69,900.00
# ABCB4                                419,600.00    602,100.00
# ABEV3                             56,058,800.00 24,151,500.00
# AERI3                                212,100.00    206,900.00
# AGRO3                                408,300.00    164,700.00
# ...                                         ...           ...
# VVEO3                              1,862,900.00    874,800.00
# WEGE3                              3,543,500.00 10,397,200.00
# WIZC3                                219,500.00    326,400.00
# YDUQ3                             16,381,600.00  4,671,300.00
# ZAMP3                                513,800.00  1,156,800.00
#
# [258 rows x 2 columns]

# %%
# bd_lista_acoes_tratada_empilhada

# bd_lista_acoes_tratada_empilhada.to_excel(var_caminho + '/Lista de ações Tratada.xlsx', index = False)

# %% [markdown]
# ## 3. detectar_martelos_todos_os_tickers e bd_acoes

# %%
import importlib
try:
    importlib.reload(sys.modules['detectar_martelos'])
except:
    pass
from detectar_martelos import detectar_martelos_todos_os_tickers

# bd_arquivo_original = pd.read_excel(r"C:\Users\ricardopeloi\OneDrive - falconi365\Data Science\O_Mais_Novo_Day_Trader_do_Brasil\o_mais_novo_day_trader_do_brasil\Bases\Lista de ações Tratada.xlsx").set_index("Ticker")
# bd_arquivo_original[bd_arquivo_original["Data da leitura (último dia útil)"] == max(bd_arquivo_original["Data da leitura (último dia útil)"])]

bd_acao_historico, bd_acoes = detectar_martelos_todos_os_tickers()
# Out:
# 220 de 252; LPSB3
# 221 de 252; IGTI3
# 222 de 252; DEXP3
# 223 de 252; TECN3
# 224 de 252; INEP4
# 225 de 252; ALPK3
# 226 de 252; AALR3
# 227 de 252; VSTE3
# 228 de 252; SANB3
# 229 de 252; RNEW11
# 230 de 252; CSUD3
# 231 de 252; ITSA3
# 232 de 252; AMBP3
# 233 de 252; DMVF3
# 234 de 252; ALLD3
# 235 de 252; OIBR4
# 236 de 252; EUCA4
# 237 de 252; PDTC3
# 238 de 252; ENGI4
# 239 de 252; UNIP6
# 240 de 252; TRAD3
# 241 de 252; GOAU3
# 242 de 252; ETER3
# 243 de 252; TPIS3
# 244 de 252; CAMB3
# 245 de 252; LVTC3
# 246 de 252; SCAR3
# 247 de 252; LUPA3
# 248 de 252; BIOM3
# 249 de 252; BOBR4
# 250 de 252; PTNT4
# 251 de 252; DEXP4
# 252 de 252; UCAS3
# === FIM DA LEITURA DOS DADOS DE HISTÓRICO ===

# %%
bd_acoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          180 non-null    datetime64[ns]
#  1   Open          180 non-null    float64
#  2   High          180 non-null    float64
#  3   Low           180 non-null    float64
#  4   Close         180 non-null    float64
#  5   Volume        180 non-null    int64
#  6   Dividends     180 non-null    float64
#  7   Stock Splits  180 non-null    float64
#  8   HLC           180 non-null    float64
#  9   Ticker        180 non-null    object
# dtypes: datetime64[ns](1), float64(7), int64(1), object(1)
# memory usage: 14.2+ KB

# %%
bd_acoes_import = pd.read_excel(r"C:\Users\ricardopeloi\OneDrive - falconi365\Data Science\O_Mais_Novo_Day_Trader_do_Brasil\o_mais_novo_day_trader_do_brasil\Bases\Base de Dados Histórico.xlsx",index_col = 0).reset_index()

bd_acoes_import.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9416 entries, 0 to 9415
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          9416 non-null   datetime64[ns]
#  1   Open          9410 non-null   float64
#  2   High          9410 non-null   float64
#  3   Low           9410 non-null   float64
#  4   Close         9410 non-null   float64
#  5   Volume        9416 non-null   int64
#  6   Dividends     9416 non-null   float64
#  7   Stock Splits  9416 non-null   float64
#  8   HLC           9410 non-null   float64
#  9   Ticker        9416 non-null   object
# dtypes: datetime64[ns](1), float64(7), int64(1), object(1)
# memory usage: 735.8+ KB

# %%
# display(datetime.today())
display(datetime.now().replace(hour=0, minute=0, second=0, microsecond=0))
# type(max(bd_acoes_import["Date"]).date())

display(datetime.now().replace(hour=0, minute=0, second=0, microsecond=0))
display(max(bd_acoes_import["Date"]).date())

acao = bd_acoes_import["Ticker"][0]
yf.Ticker(acao + ".SA").history(
    # start = max(bd_acoes_import["Date"]).date(),
    start = datetime.today(),
    end = datetime.today(),
    interval = "1d"
)
# Out:
# datetime.datetime(2025, 4, 26, 0, 0)
# datetime.datetime(2025, 4, 26, 0, 0)
# datetime.date(2025, 4, 25)
# $HAPV3.SA: possibly delisted; no price data found  (1d 2025-04-26 18:36:11.466739 -> 2025-04-26 18:36:11.466743)
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
bd_acoes_empilhada = pd.concat([bd_acoes_import, bd_acoes]).drop_duplicates(subset = ["Date", "Ticker"])

display(bd_acoes_empilhada[bd_acoes_empilhada["Open"].isna()])
display(bd_acoes_empilhada)
# Out:
#            Date  Open  High  Low  Close  Volume  Dividends  Stock Splits  HLC  \
# 665  2025-04-25   NaN   NaN  NaN    NaN       0       0.20          0.00  NaN
# 1576 2025-04-25   NaN   NaN  NaN    NaN       0       0.05          0.00  NaN
# 2137 2025-04-25   NaN   NaN  NaN    NaN       0       0.21          0.00  NaN
# 2768 2025-04-25   NaN   NaN  NaN    NaN       0       0.06          0.00  NaN
# 6094 2025-04-25   NaN   NaN  NaN    NaN       0       0.69          0.00  NaN
# 8853 2025-04-25   NaN   NaN  NaN    NaN       0       0.07          0.00  NaN
#
#      Ticker
# 665   CPLE6
# 1576  ANIM3
# 2137  CPLE3
# 2768  AURE3
# 6094  BMOB3
# 8853  LAND3
#            Date  Open  High  Low  Close    Volume  Dividends  Stock Splits  \
# 0    2025-03-05  2.07  2.14 1.98   2.13  77802900       0.00          0.00
# 1    2025-03-06  2.13  2.16 2.07   2.08  66517100       0.00          0.00
# 2    2025-03-07  2.08  2.22 2.06   2.17  97225000       0.00          0.00
# 3    2025-03-10  2.14  2.15 2.05   2.05  78062300       0.00          0.00
# 4    2025-03-11  2.06  2.09 2.03   2.06  59563500       0.00          0.00
# ...         ...   ...   ...  ...    ...       ...        ...           ...
# 9411 2025-04-22  7.59  7.70 7.59   7.63      3900       0.00          0.00
# 9412 2025-04-23  7.68  7.70 7.63   7.69     14200       0.00          0.00
# 9413 2025-04-24  7.68  7.80 7.68   7.80      8700       0.00          0.00
# 9414 2025-04-25  7.79  7.85 7.79   7.81     20700       0.00          0.00
# 9415 2025-04-25  1.58  1.63 1.58   1.58     20100       0.00          0.00
#
#       HLC Ticker
# 0    2.08  HAPV3
# 1    2.10  HAPV3
# 2    2.15  HAPV3
# 3    2.08  HAPV3
# 4    2.06  HAPV3
# ...   ...    ...
# 9411 7.64  DEXP4
# 9412 7.67  DEXP4
# 9413 7.76  DEXP4
# 9414 7.82  DEXP4
# 9415 1.60  UCAS3
#
# [9416 rows x 10 columns]

# %%
import importlib
try:
    importlib.reload(sys.modules['detectar_martelos'])
except:
    pass
from detectar_martelos import candle_plot

# var_acao = "HAPV3"
var_acao = "VAMO3"

display(bd_acoes_empilhada[bd_acoes_empilhada["Ticker"] == var_acao])

candle_plot( # Usa o navegador para criar o gráfico interativo
    bd_acoes_empilhada[bd_acoes_empilhada["Ticker"] == var_acao].set_index("Date"),
    volume = True,
    mav = np.nan,
    colors = ["orange", "yellow", "blue"],
    titulo = "",
)
# Out:
#            Date  Open  High  Low  Close    Volume  Dividends  Stock Splits  \
# 1016 2025-03-05  3.85  3.90 3.68   3.70   7801900       0.00          0.00
# 1017 2025-03-06  3.75  3.78 3.59   3.65  11312000       0.00          0.00
# 1018 2025-03-07  3.65  3.95 3.59   3.82  13260500       0.00          0.00
# 1019 2025-03-10  3.77  3.90 3.71   3.75   8562400       0.00          0.00
# 1020 2025-03-11  3.77  3.84 3.70   3.77   8460700       0.00          0.00
# 1021 2025-03-12  3.76  3.86 3.67   3.71   6936900       0.00          0.00
# 1022 2025-03-13  3.70  3.72 3.54   3.58  10969800       0.00          0.00
# bd_acoes_import.info()

import importlib
try:
    importlib.reload(sys.modules['detectar_martelos'])
except:
    pass
from detectar_martelos import candle_plot

var_acao = "HAPV3"
# var_acao = "VAMO3"

# display(bd_acoes_import[bd_acoes_import["Ticker"] == var_acao])

candle_plot( # Usa o navegador para criar o gráfico interativo
    bd_acoes_import[bd_acoes_import["Ticker"] == var_acao].set_index("Date"),
    volume = True,
    mav = np.nan,
    colors = ["orange", "yellow", "blue"],
    titulo = "",
)

# %% [markdown]
# ## 5. detectar_martelos_todos_os_tickers e bd_acao_historico

# %%
bd_acao_historico
# Out:
#   Ticker   Nome da Empresa  Volume no último dia útil  \
# 0  AZUL4              Azul                  282174900
# 1  CRFB3  Carrefour Brasil                   65204900
# 2  HAPV3           Hapvida                   64731600
# 3  COGN3             Cogna                   37935400
# 4  B3SA3                B3                   37609700
#
#   Data da leitura (último dia útil)                          industry  \
# 0                        2025-04-26                          Airlines
# 1                        2025-04-26                 Department Stores
# 2                        2025-04-26                  Insurance - Life
# 3                        2025-04-26     Education & Training Services
# 4                        2025-04-26  Financial Data & Stock Exchanges
#
#                sector  fullTimeEmployees  dividendRate  dividendYield  \
# 0         Industrials          15,367.00           NaN            NaN
# 1   Consumer Cyclical                NaN          0.10           1.11
# 2  Financial Services                NaN           NaN            NaN
# 3  Consumer Defensive          24,187.00          0.26          10.48
# 4  Financial Services                NaN          0.25           1.88
#
#     exDividendDate  ...  2025-04-25; Low  2025-04-25; Close  \
# 0              NaN  ...             1.94               1.95
# 1 1,745,971,200.00  ...             8.53               8.64
# 2 1,640,649,600.00  ...             2.37               2.41
# 3 1,745,884,800.00  ...             2.48               2.50
# 4 1,742,947,200.00  ...            13.04              13.39
#
#    2025-04-25; Volume  2025-04-25; Dividends  2025-04-25; Stock Splits  \
# 0           282174900                   0.00                      0.00
# 1            65204900                   0.00                      0.00
# 2            64738600                   0.00                      0.00
# 3            37935400                   0.00                      0.00
# 4            37617800                   0.00                      0.00
#
#    2025-04-25; HLC  Alfa HLC; últimos 13 dias  Alfa HLC; últimos 55 dias  \
# 0             2.10                      -0.04                      -0.03
# 1             8.64                       0.04                       0.04
# 2             2.41                       0.02                       0.00
# 3             2.51                       0.04                       0.03
# 4            13.29                       0.10                       0.05
#
#                                             Martelos  \
# 0  2025-03-05, 2025-03-10, 2025-03-12, 2025-03-19...
# 1  2025-03-11, 2025-03-17, 2025-04-02, 2025-04-08...
# 2  2025-03-11, 2025-03-13, 2025-03-26, 2025-04-01...
# 3  2025-03-06, 2025-03-17, 2025-03-20, 2025-03-21...
# 4  2025-03-21, 2025-03-26, 2025-03-27, 2025-03-28...
#
#                                    Tipos de Martelos
# 0  Descida, Descida, Descida, Subida, Descida, Su...
# 1  Subida, Subida, Descida, Subida, Descida, Desc...
# 2  Subida, Subida, Subida, Subida, Subida, Subida...
# 3  Subida, Subida, Subida, Subida, Subida, Subida...
# 4  Subida, Descida, Descida, Descida, Subida, Sub...
#
# [5 rows x 355 columns]
